# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost",user="root", passwd="mysql123",use_pure=True)
    # check if the connection is established

    query = "SHOW DATABASES"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    #print(cursor.fetchall())

except Exception as e:
    mydb.close()
    print(str(e))

# %%
import mysql.connector as connection

# %%
conn = connection.connect(host="localhost",user="root", passwd="mysql123",use_pure=True)

# %%
cur = conn.cursor()

# %%
cur.execute("show databases")

# %%
res = cur.fetchall()

# %%
res
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sys',)]

# %%
res[1]
# Out:
# ('mysql',)

# %%
res[1][0]
# Out:
# 'mysql'

# %%
for i in res:
    print(i[0])
# Out:
# information_schema
# mysql
# performance_schema
# sys

# %%
#creating database

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost",user="root", passwd="mysql123",use_pure=True)
    # check if the connection is established

    query = "CREATE DATABASES"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute("create database khan1")
    #print(cursor.fetchall())

except Exception as e:
    mydb.close()
    print(str(e))

# %%
#creating table

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'khan1',user="root", passwd="mysql123",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE StudentDetails (Studentid INT(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR(60)," \
            "LastName VARCHAR(60), RegistrationDate DATE,Class Varchar(20), Section Varchar(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'studentdetails' already exists

# %%
mydb.is_connected()
# Out:
# True

# %%
import mysql.connector as connection

# %%
    mydb = connection.connect(host="localhost", database = 'khan1',user="root", passwd="mysql123",use_pure=True)

# %%
mydb.is_connected()
# Out:
# True

# %%
cur = mydb.cursor()

# %%
cur.execute("create table khan1(x1 INT(5),x2 VARCHAR(20),x3 DATE)")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [131], in <cell line: 1>()
# ----> 1 cur.execute("create table khan1(x1 INT(5),x2 VARCHAR(20),x3 DATE)")
#       2 mydb.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/cursor.py:564, in MySQLCursor.execute(self, operation, params, multi)
#     561     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     563 try:
# --> 564     self._handle_result(self._connection.cmd_query(stmt))
#     565 except InterfaceError as err:
#     566     if self._connection.have_next_result:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:990, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     988 query = bytes(packet)
#     989 try:
# --> 990     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
# ...

# %%
mydb.close()

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'khan1',user="root", passwd="mysql123",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE StudentDetails (Studentid INT(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR(60)," \
            "LastName VARCHAR(60), RegistrationDate DATE,Class Varchar(20), Section Varchar(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'studentdetails' already exists

# %%
mydb = connection.connect(host="localhost", database = 'khan1',user="root", passwd="mysql123",use_pure=True)

# %%
cur = mydb.cursor()

# %%
    print(mydb.is_connected())
# Out:
# True

# %%
cur.execute("insert into khan1 values(2223,'shayan','2022.11.17')")#yyyy.mm.dd

# %%
#commit it

# %%
mydb.commit()

# %%
cur.execute("insert into khan1 values(2223,'shayan','2022.11.17')")
cur.execute("insert into khan1 values(2223,'shayan','2022.11.17')")
cur.execute("insert into khan1 values(2223,'shayan','2022.11.17')")

# %%
#fetching data from database

# %%
cur = mydb.cursor()

# %%
out = cur.execute("select * from khan1")

# %%
cur.fetchall()
# Out:
# [(2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
#  (2223, 'shayan', datetime.date(2022, 11, 17)),
# ...

# %%
for i in cur.fetchall():
    print(i)

# %%
#selecting 2 columns

# %%
cur = mydb.cursor()

# %%
cur.execute("select x1,x2 from khan1")

# %%
for i in cur.fetchall():
    print(i)
# Out:
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')
# (2223, 'shayan')

# %%
# reading data into tabuler format

# %%
import pandas as pd

# %%
mydb

# %%
pd.read_sql("select * from khan1.khan1",mydb)#data base name and table name
# Out:
#       x1      x2          x3
# 0   2223  shayan  2022-11-17
# 1   2223  shayan  2022-11-17
# 2   2223  shayan  2022-11-17
# 3   2223  shayan  2022-11-17
# 4   2223  shayan  2022-11-17
# 5   2223  shayan  2022-11-17
# 6   2223  shayan  2022-11-17
# 7   2223  shayan  2022-11-17
# 8   2223  shayan  2022-11-17
# 9   2223  shayan  2022-11-17
# 10  2223  shayan  2022-11-17
# 11  2223  shayan  2022-11-17
# 12  2223  shayan  2022-11-17
# 13  2223  shayan  2022-11-17
# 14  2223  shayan  2022-11-17
# 15  2223  shayan  2022-11-17
# 16  2223  shayan  2022-11-17
# 17  2223  shayan  2022-11-17
# 18  2223  shayan  2022-11-17
# 19  2223  shayan  2022-11-17
# 20  2223  shayan  2022-11-17
# 21  2223  shayan  2022-11-17
# 22  2223  shayan  2022-11-17
# 23  2223  shayan  2022-11-17
# 24  2223  shayan  2022-11-17
# 25  2223  shayan  2022-11-17
# 26  2223  shayan  2022-11-17
# 27  2223  shayan  2022-11-17
# 28  2223  shayan  2022-11-17

# %%
pd.read_sql("select x2,x3 from khan1",mydb)
# Out:
# /Users/daudkhan/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#         x2          x3
# 0   shayan  2022-11-17
# 1   shayan  2022-11-17
# 2   shayan  2022-11-17
# 3   shayan  2022-11-17
# 4   shayan  2022-11-17
# 5   shayan  2022-11-17
# 6   shayan  2022-11-17
# 7   shayan  2022-11-17
# 8   shayan  2022-11-17
# 9   shayan  2022-11-17
# 10  shayan  2022-11-17
# 11  shayan  2022-11-17
# 12  shayan  2022-11-17
# 13  shayan  2022-11-17
# 14  shayan  2022-11-17
# 15  shayan  2022-11-17
# 16  shayan  2022-11-17
# 17  shayan  2022-11-17
# 18  shayan  2022-11-17
# 19  shayan  2022-11-17
# 20  shayan  2022-11-17
# 21  shayan  2022-11-17
# 22  shayan  2022-11-17
# 23  shayan  2022-11-17
# 24  shayan  2022-11-17
# 25  shayan  2022-11-17
# 26  shayan  2022-11-17
# ...

# %%
#dumping data direct into sql

# %%
a = pd.read_sql("select x2,x3 from khan1",mydb)
# Out:
# /Users/daudkhan/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
a.to_sql
# Out:
# <bound method NDFrame.to_sql of         x2          x3
# 0   shayan  2022-11-17
# 1   shayan  2022-11-17
# 2   shayan  2022-11-17
# 3   shayan  2022-11-17
# 4   shayan  2022-11-17
# 5   shayan  2022-11-17
# 6   shayan  2022-11-17
# 7   shayan  2022-11-17
# 8   shayan  2022-11-17
# 9   shayan  2022-11-17
# 10  shayan  2022-11-17
# 11  shayan  2022-11-17
# 12  shayan  2022-11-17
# 13  shayan  2022-11-17
# 14  shayan  2022-11-17
# 15  shayan  2022-11-17
# 16  shayan  2022-11-17
# 17  shayan  2022-11-17
# 18  shayan  2022-11-17
# 19  shayan  2022-11-17
# 20  shayan  2022-11-17
# 21  shayan  2022-11-17
# 22  shayan  2022-11-17
# 23  shayan  2022-11-17
# 24  shayan  2022-11-17
# 25  shayan  2022-11-17
# 26  shayan  2022-11-17
# 27  shayan  2022-11-17
# 28  shayan  2022-11-17>

# %%
a.to_csv("mydata.csv") #saving data into csv

# %%
mydb = connection.connect(host="localhost", database = 'khan1',user="root", passwd="mysql123",use_pure=True)

# %%
mydb

# %%
data = pd.read_csv("mydata.csv")

# %%
data
# Out:
#     Unnamed: 0      x2          x3
# 0            0  shayan  2022-11-17
# 1            1  shayan  2022-11-17
# 2            2  shayan  2022-11-17
# 3            3  shayan  2022-11-17
# 4            4  shayan  2022-11-17
# 5            5  shayan  2022-11-17
# 6            6  shayan  2022-11-17
# 7            7  shayan  2022-11-17
# 8            8  shayan  2022-11-17
# 9            9  shayan  2022-11-17
# 10          10  shayan  2022-11-17
# 11          11  shayan  2022-11-17
# 12          12  shayan  2022-11-17
# 13          13  shayan  2022-11-17
# 14          14  shayan  2022-11-17
# 15          15  shayan  2022-11-17
# 16          16  shayan  2022-11-17
# 17          17  shayan  2022-11-17
# 18          18  shayan  2022-11-17
# 19          19  shayan  2022-11-17
# 20          20  shayan  2022-11-17
# 21          21  shayan  2022-11-17
# 22          22  shayan  2022-11-17
# 23          23  shayan  2022-11-17
# 24          24  shayan  2022-11-17
# 25          25  shayan  2022-11-17
# ...

# %%
pd.read_sql("select * from khan1",mydb) #reading all data
# Out:
# /Users/daudkhan/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       x1      x2          x3
# 0   2223  shayan  2022-11-17
# 1   2223  shayan  2022-11-17
# 2   2223  shayan  2022-11-17
# 3   2223  shayan  2022-11-17
# 4   2223  shayan  2022-11-17
# 5   2223  shayan  2022-11-17
# 6   2223  shayan  2022-11-17
# 7   2223  shayan  2022-11-17
# 8   2223  shayan  2022-11-17
# 9   2223  shayan  2022-11-17
# 10  2223  shayan  2022-11-17
# 11  2223  shayan  2022-11-17
# 12  2223  shayan  2022-11-17
# 13  2223  shayan  2022-11-17
# 14  2223  shayan  2022-11-17
# 15  2223  shayan  2022-11-17
# 16  2223  shayan  2022-11-17
# 17  2223  shayan  2022-11-17
# 18  2223  shayan  2022-11-17
# 19  2223  shayan  2022-11-17
# 20  2223  shayan  2022-11-17
# ...

# %%
pd.read_sql("select * from mydata",mydb) #reading all data
# Out:
# Empty DataFrame
# Columns: [n1, n2, n3]
# Index: []

# %%
#writing a data into bulk in my data base

# %%
#1  establish connection
#   2 create a table
#   3 write in bulk
#   4 commit

# %%
import mysql.connector as connection

# %%
import pandas as pandas

# %%
import csv

# %%
#establishing connection

# %%
mydb = connection.connect(host="localhost",user="root", passwd="mysql123",use_pure=True)

# %%
#checking conenction
mydb.is_connected()
# Out:
# True

# %%
# i would like to store it in my existing database khan 1 and create a new table GlassData

# %%
cur = mydb.cursor()

# %%
cur.execute("create table khan1.GlassData(index_NUMBER int(10.5),khano float(10.5),Na float(10.5),Mg float(10.5),Al float(10.5),Si float(10.5),K float(10.5),Ca float(10.5),Ba float(10.5),Fe float(10.5),Class float(10.5))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 cur.execute("create table khan1.GlassData(index_NUMBER int(10.5),khano float(10.5),Na float(10.5),Mg float(10.5),Al float(10.5),Si float(10.5),K float(10.5),Ca float(10.5),Ba float(10.5),Fe float(10.5),Class float(10.5))")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/cursor.py:564, in MySQLCursor.execute(self, operation, params, multi)
#     561     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     563 try:
# --> 564     self._handle_result(self._connection.cmd_query(stmt))
#     565 except InterfaceError as err:
#     566     if self._connection.have_next_result:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py:990, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
# ...

# %%
with open("/Users/daudkhan/Downloads/19.2.MySQL/glass.data/Glass.data")#not working
# Out:
#   Input In [28]
#     with open("/Users/daudkhan/Downloads/19.2.MySQL/glass.data/Glass.data")#not working
#                                                                            ^
# SyntaxError: invalid syntax

# %%
# !ls
# Out:
#  stings and list Manipulation.ipynb
# Applications
# DIctionaries.ipynb
# Desktop
# Dictionary in Python Explained.ipynb
# Documents
# Downloads
# For loop and Range Function.ipynb
# Functions in python.ipynb
# Input Function in Python.ipynb
# Library
# Lists.ipynb
# Movies
# Music
# Pictures
# Public
# PycharmProjects
# String and list manipulation part 2.ipynb
# Untitled Folder
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled17.ipynb
# Untitled18.ipynb
# Untitled19.ipynb
# Untitled2.ipynb
# Untitled20.ipynb
# Untitled21.ipynb
# Untitled22.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# Variable & Strings.ipynb
# Variable and Strings.ipynb
# __pycache__
# abstraction and inheritance.ipynb
# addition.py
# additionn.py
# classes and objects.ipynb
# ...

# %%
pwd # i will change location and alocate the glassdata file
# Out:
# '/Users/daudkhan'

# %%
with open('glass.data','r') as data:
    data_csv = csv.reader(data,delimiter='\n')
    print(data_csv)
    for i in data_csv:
        print(i)
# Out:
# ...
# ['index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class']
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ...

# %%
#giving indexing we will use enumerate

# %%
with open('glass.data','r') as data:
    data_csv = csv.reader(data,delimiter='\n')
    print(data_csv)
    for i in enumerate(data_csv):
        print(i)
# Out:
# ...
# (0, ['index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class'])
# (1, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# (2, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# (3, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# (4, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# (5, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# (6, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# (7, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# (8, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# (9, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# (10, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# (11, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# (12, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# (13, ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'])
# (14, ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'])
# ...

# %%
#i will add all the list into specific table
with open('glass.data','r') as data:
    next(data)
    data_csv = csv.reader(data,delimiter='\n')
    print(data_csv)
    for i in enumerate(data_csv):
        print(i)
        for j in i[1]:
            cur.execute('insert into khan1.GlassData values ({data})'.format(data =(j)))
    print("all data is inserted")
mydb.commit()
# Out:
# ...
# (0, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# (1, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# (2, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# (3, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# (4, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# (5, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# (6, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# (7, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# (8, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# (9, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# (10, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# (11, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# (12, ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'])
# (13, ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'])
# (14, ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1'])
# ...
